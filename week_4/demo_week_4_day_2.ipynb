# %% [markdown]
# ## Data Analysis using Python
# ## Week 4, Day 2: Machine Learning Intro.

# %% [markdown]
# In this lesson, we’ll explore two fundamental types of supervised machine learning models:
#
# 1. Regression: Used for predicting continuous values.
# 2. Classification: Used for categorizing data into predefined classes.

# %% [markdown]
# ![Reg vs Class](https://www.simplilearn.com/ice9/free_resources_article_thumb/Regression_vs_Classification.jpg)
#
# ![Reg vs Class](https://i0.wp.com/www.sharpsightlabs.com/wp-content/uploads/2021/04/regression-vs-classification_simple-comparison-image_v3.png?w=682&ssl=1)

# %% [markdown]
# ### 1. Regression Model
#
# Regression is a supervised learning technique used to predict a continuous target variable based on one or more input features. For example:
#
# Predicting a patient's medical bill based on age, gender, and the reason for their visit.

# %% [markdown]
# #### 1.1 Step 1: Import Libraries

# %% [markdown]
# #### 1.2 Step 2: Prepare the Data

# %%
# Load the insurance dataset

# %%
# One-hot encode categorical columns

# %%
# Separate features (X) and target (y)

# %%
# Split into training and testing sets

# %% [markdown]
# #### 1.3 Step 3: Train the Model

# %%
# Initialize and train the Linear Regression model

# %%
# Print model coefficients

# %% [markdown]
# #### 1.4 Step 4: Evaluate the Model

# %%
# Predict on test data

# %%
# Evaluate using R²

# %% [markdown]
# #### 1.5 Step 5: Visualize Results

# %%
# Scatter plot for actual vs predicted charges

# %% [markdown]
# ### 2. Classification Model
# What is Classification?
# Classification is a supervised learning technique used to assign data points to predefined categories. For example:
#
# * Classifying patients as having "High Risk" or "Low Risk" based on medical history.

# %% [markdown]
# #### 2.1 Step 1: Import Libraries

# %%
# Import libraries

# %% [markdown]
# #### 2.2 Step 2: Prepare the Data

# %%
# Load the cancer dataset

# %%
# Encode the target variable

# %%
# Separate features (X) and target (y)

# %%
# Split into training and testing sets

# %% [markdown]
# #### 2.3 Step 3: Train the Model

# %%
# Initialize and train the Random Forest model

# %% [markdown]
# #### 2.4 Step 4: Evaluate the Model

# %%
# Predict on test data

# %%
# Evaluate the model

# %% [markdown]
# #### 2.5 Step 5: Visualize Results

# %%
# Display confusion matrix

# %%
# Plot feature importance
