# %% [markdown]
# ## Data Analysis using Python
# ## Week 4, Day 1: Data Visulization

# %% [markdown]
# ### 1. Matplotlib

# %% [markdown]
# #### 1.1 Line Plot
# **Purpose:** Show how the copay_amount varies across appointment dates.

# %%
# import pandas and matplotlib

# read the files patients.xlsx and appointments.xlsx

# %%
# Ensure appointment_date is in datetime format

# %%
# Sort by date for better visualization

# %%
# Calculate average copay_amount for each day

# %%
# Set plot size and data

# Set title ('Trends in Copay Amount Over Time'), xlabel and ylabel with font sizes 14 and 12

# rotate xticks then show the plot

# %% [markdown]
# #### 1.2 Bar Plot
# **Purpose:** Display the distribution of appointments across the top 10 doctors.

# %%
# Count the number of appointments per doctor and get the top 10

# %%
# Set plot size and data

# Set title ('Number of Appointments per Doctor'), xlabel and ylabel with font sizes 14 and 12

# show the plot

# %% [markdown]
# #### 1.3 Pie Chart
# **Purpose:** Show the proportion of each blood type in the patient population.

# %%
# Count the distribution of blood types

# %%
# Plot the pie chart, set title ('Distribution of Blood Types') and show the plot
# show the autopct with 1 decimal place
# use colors = ['lightcoral', 'gold', 'skyblue', 'lightgreen'] for the pie chart

# %% [markdown]
# #### 1.4 Histogram
# **Purpose:** Visualize the age distribution in the patients' dataset.

# %%
# Plot the histogram ('Age Distribution of Patients')
# Use bins 20 and different colors for fill and edge
# Show grid as horizontal dashed lines

# %% [markdown]
# #### 1.5 Scatter Plot
# **Purpose:** Explore the relationship between a patient's age and their copay amount.

# %%
# Merge the datasets on patient_id

# %%
# Plot the pie ('Age vs. Copay Amount')
# Show grid dashed lines and 70% alpha

# %% [markdown]
# #### 1.6 Horizontal Bar Chart
# **Purpose:** Display average copay amounts for each insurance_provider in a horizontal bar chart for better readability.

# %%
# Calculate average copay amount by insurance provider

# %%
# Plot the horizontal bar chart

# %% [markdown]
# #### 1.7 Subplots
# **Purpose:** Use subplots to visualize multiple charts in one figure.

# %%
# Create 2 by 2 subplots

# %%
# Plot 1: Histogram of Age

# %%
# Plot 2: Pie chart of Blood Types

# %%
# Plot 3: Bar chart of Appointments per Doctor

# %%
# Plot 4: Horizontal Bar chart of Average Copay Amount per insurance provider

# %% [markdown]
# ### 2. Seaborn Visualizations
# The Seaborn library provides enhanced aesthetics and functionality for visualizing data. Below are examples using Seaborn.

# %% [markdown]
# #### 2.1 Scatter Plot with Regression Line
# **Purpose:** Show the relationship between `age` and `copay_amount` with a regression line.

# %%
# seaborn library

# %%
# Scatter plot with regression line (regplot)
# color the dots blue and the line red

# %% [markdown]
# #### 2.2 Heatmap
# **Purpose:** Visualize the correlation between numerical variables.

# %%
# Compute correlation matrix with the method `corr`

# %%
# Compute correlation matrix


# Plot heatmap, show the correlation values with 2 decimal places and hide the cbar

# %%
# Count the values in each group

# %% [markdown]
# #### 2.3 Count Plot
# **Purpose:** Display the number of appointments per month.

# %%
# Count plot of appointments by month

# %% [markdown]
# #### 2.4 Grouped Count Plot
# **Purpose:** Show the number of appointments for each month, grouped by insurance provider.

# %%
# Plot the grouped countplot

# %% [markdown]
# ### **Challenge: Age and Copay Correlation**
#
# 🏥 **Scenario**: Management wants to understand how age correlates with copay amounts for different reasons for visits. They also want to visualize the overall age distribution.
#
# #### **Tasks**:
#
# 1.  **Scatter Plot with Regression Line**:
#
#     -   Plot a scatter plot of `age` vs. `copay_amount`, with a regression line.
#     -   Use different colors or markers to distinguish `reason_for_visit`.
# 2.  **Histogram**:
#
#     -   Create a histogram to show the distribution of patient ages.
#     -   Use different bins (e.g., bin sizes of 10 years).
#
# #### **Deliverables**:
#
# -   Insights into whether there’s a relationship between age and copay amounts.
# -   Code implementation for both plots.
