# %% [markdown]
# ## Data Analysis using Python
# ## Week 2, Day 1: Data Cleaning

# %% [markdown]
# ### 1. Handling Missing Data

# %% [markdown]
# #### 1.1 Identifying Missing Data
# To identify missing values, use `.isnull()` or `.notnull()`
#  combined with `.sum()` to count them.

# %%
#import pandas

# %%
# read the file Lab Test Results.xlsx

# %%
# Check for missing values in the Lab Test Results dataset with isnull() method

# %%
# Count missing values per column

# %%
# Count total values

# %% [markdown]
# #### 1.2 Dropping Rows with Missing Values
# **Function:** `dropna()`
#
# **Description:** Removes rows or columns containing missing values.
#
# **Key Parameters:**
#   * `subset`: Specifies which columns to check for missing values.
#   * `how`: Determines how missing values are handled ('any' to drop rows with any NaN, 'all' to drop rows with all NaN).
#   * `axis`: 0 for rows (default) or 1 for columns.

# %%
# Drop rows where any column has a missing value dropna()

# %%
# Drop rows where the column `Result Value` have missing values

# %%
# Drop columns with missing values

# %% [markdown]
# #### 1.3 Filling Missing Values
# **Function:** `fillna()`
#
# **Description:** Replaces missing values with specified values.
#
# **Key Parameters:**
#   * `value`: The value to fill missing entries (can be a scalar, dictionary, or Series).
#   * `method`: Use 'ffill' (forward fill) or 'bfill' (backward fill).
#   * `inplace`: If True, modifies the DataFrame in place without returning a new one.

# %%
# Fill missing Result Values with "Unknown"

# %%
# Read the file Lab Test Orders.xlsx

# %%
# Fill missing Priority with "Medium" and missing Order Status with "Pending"

# %%
# Fill missing values using the last valid value

# %%
# Fill missing values using the next valid value

# %% [markdown]
# ### 2. Removing Duplicates

# %% [markdown]
# #### 2.1 Identifying Duplicates
# **Function:** `duplicated()`
#
# **Description:** Identifies duplicate rows in the DataFrame.
#
# **Key Parameters:**
#   * `subset`: Specifies which columns to check for duplicates (default is all columns).
#   * `keep`: Determines which duplicate to mark (`first` to mark all but the first occurrence, `last` to mark all but the last, `False` to mark all duplicates).

# %%
# Find rows that are duplicates of previous ones

# %%
# Check for duplicates based only on 'Patient ID' and 'Order Date'

# %%
# Check for duplicates based only on 'Order Date'

# %%
# Mark all duplicates based only on 'Order Date' (including the first occurrence)

# %% [markdown]
# #### 2.2 Removing Duplicates
# **Function:** `drop_duplicates()`
#
# **Description:** Removes duplicate rows from the DataFrame.
#
# **Key Parameters:**
#   * `subset`: Specifies which columns to consider for identifying duplicates.
#   * `keep`: Determines which duplicate to keep (`first`, `last`, or `False` to remove all duplicates).
#   * `inplace`: If `True`, modifies the DataFrame in place without returning a new one.

# %%
# Remove duplicates while keeping the first occurrence

# %%
# Remove duplicates while keeping the last occurrence

# %%
# Remove all duplicate rows completely

# %% [markdown]
# ### 3. Transforming Data

# %% [markdown]
# #### 3.1 Formatting Columns
# **Function:** `pd.to_datetime()`
#
# **Description:** Converts a column to datetime format.
#
# **Key Parameters:**
#   * `format`: Custom date-time format (e.g., %d-%m-%Y).
#   * `errors`: Handling of conversion errors ('raise', 'coerce', or 'ignore').

# %%
# Read the file appointments.xlsx

# %%
# show the columns Datatypes

# %%
# Convert appointment_date with a custom format %m/%d/%Y

# %%
# show the columns Datatypes

# %%
# change one date in the appointments file and make it wrong
# read the file again

# %%
# Convert appointment_date with a custom format %m/%d/%Y and ignore invalid entries

# %%
# show the columns Datatypes

# %% [markdown]
# #### 3.2 Extracting Information
# **Function:** `dt` accessor
#
# **Description:** Access datetime properties like year, month, day, etc.

# %%
# Add a new column for the year

# %%
# Extract the month from appointment_date

# %%
# Extract the month name from appointment_date

# %%
# Extract the weekday from appointment_date

# %% [markdown]
# #### 3.3 Splitting Text Columns
# **Function:** `str.split()`
#
# **Description:** Splits strings into a list based on a delimiter.
#
# **Key Parameters:**
#   * `pat`: The delimiter to split on (default is whitespace).
#   * `n`: Maximum number of splits (default is -1 for no limit).
#   * `expand`: If True, returns a DataFrame with separate columns for splits.

# %%
# Extract each word in Test Names

# %%
# Split Test Names into separate columns

# %% [markdown]
# #### 3.4 Cleaning Column Data
# **Function:** `str.replace()`
#
# **Description:** Replaces occurrences of a string with another.
#
# **Key Parameters:**
#   * `pat`: The string or regex pattern to replace.
#   * `repl`: The replacement string.
#   * `regex`: If `True`, treats pat as a regex pattern (default is `True`).

# %%
# Replace "Normal" with "Within Range" in Result Value

# %%
# Remove non-numeric characters from Result Value

# %% [markdown]
# #### 3.5 Renaming Columns
# **Function:** `rename()`
#
# **Description:** Renames columns or rows in a DataFrame to make them more descriptive or aligned with standards.
#
# **Key Parameters:**
#   * `columns`: A dictionary mapping old column names to new ones.
#   * `index`: A dictionary mapping old row indices to new ones.
#   * `inplace`: If `True`, modifies the DataFrame in place without returning a new one (default is `False`).

# %%
# Rename column Patient ID to MRN

# %%
# Rename columns directly in the original DataFrame

# %%
# Rename specific row indices

# %% [markdown]
# #### 3.6 Applying Custom Functions
# **Function:** `apply()`
#
# **Description:** Applies a function along an axis (rows or columns) of the DataFrame to transform data.
#
# **Key Parameters:**
#   * `func`: The function to apply. Can be a custom function, a lambda, or a built-in Python function.
#   * `axis`: Determines whether to apply the function to rows (`axis=1`) or columns (`axis=0`).
#   * `raw`: If `True`, passes the data as a NumPy array to the function, improving performance (default is `False`).

# %%
# Apply upper() function to transform Test Names to uppercase

# %%
# Categorize Priority as "ASAP" if High, otherwise "Routine"

# %%
# Combine Doctor ID and Patient ID into a unique identifier

# %% [markdown]
# ### **Challenge 1: Clean and Transform the Lab Test Orders Dataset**
#
# 🏥  **Scenario**: The  **Lab Test Orders**  dataset contains issues such as missing data, duplicate entries, and unstructured columns. Your task is to clean and transform the dataset into a more usable form.
#
# #### **Instructions**:
#
# 1.  **Handle Missing Data**:
#
#     -   Identify and count all missing values in the dataset.
#     -   Replace missing values in the  `Priority`  column with  `"Medium"`.
#     -   Drop rows where the  `Order ID`  or  `Order Status`  is missing.
# 2.  **Remove Duplicates**:
#
#     -   Check for duplicate rows.
#     -   Remove duplicates while keeping the first occurrence.
# 3.  **Transform Data**:
#
#     -   Rename the column  `"Test Names"`  to  `"Ordered Tests"`.
#     -   Extract the first word from the  `"Ordered Tests"`  column into a new column called  `"Primary Test"`.
#     -   Create a new column  `"Urgency Level"`:
#         -   Assign  `"Critical"`  for  `"High"`  priority.
#         -   Assign  `"Routine"`  for all other priorities.

# %% [markdown]
# ### **Challenge 2: Analyze and Enrich the Appointments Dataset**
#
# 🏥  **Scenario**: The  **Appointments**  dataset has missing values, duplicate entries, and inconsistencies. Clean and enrich the data to prepare it for analysis.
#
# #### **Instructions**:
#
# 1.  **Handle Missing Data**:
#
#     -   Identify all columns with missing data and count the missing values.
#     -   Fill missing values in the  `"copay_amount"`  column with the column's mean.
#     -   Drop rows where the  `"appointment_id"`  or  `"patient_id"`  is missing.
# 2.  **Remove Duplicates**:
#
#     -   Identify duplicate rows based on the combination of  `"appointment_id"`  and  `"appointment_date"`.
#     -   Remove all duplicate rows while keeping the last occurrence.
# 3.  **Transform Data**:
#
#     -   Convert the  `"appointment_date"`  column to a datetime format.
#     -   Extract the month and year into new columns called  `"Appointment Month"`  and  `"Appointment Year"`.
#     -   Categorize  `"copay_amount"`  into:
#         -   `"Low"`  if less than 0.2.
#         -   `"Medium"`  if between 0.2 and 0.5.
#         -   `"High"`  if greater than 0.5.
