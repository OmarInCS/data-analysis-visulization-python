# %% [markdown]
# ## Data Analysis using Python
# ## Week 3, Day 2: Data Aggregation

# %% [markdown]
# ### 1. Data Aggregation
#
# ![image.png](attachment:image.png)
#
# #### 1.1 Grouping & Aggregation
# * Grouping in pandas can be performed using the `groupby` method, which allows grouping by one or more columns.
# * Once the data is grouped, aggregation functions can be applied to compute summary statistics for each group.

# %%
# Group appointments by 'insurance_provider'

# %%
# Calculate average copay amount

# %% [markdown]
# #### 1.2 Applying Multiple Aggregation Functions
# Pandas allows the application of multiple aggregation functions simultaneously using the `agg` method.

# %%
# Apply multiple aggregations

# %% [markdown]
# #### 1.3 Aggregating Multiple Columns
# Aggregation can also be performed on multiple columns simultaneously.

# %%
# Calculate average copay and number of appointments for each doctor

# %%
# rename the columns 'average_copay' and 'appointment_count'

# %% [markdown]
# #### 1.4 Custom Aggregation Functions
# Custom functions can be applied to groups using the `agg` method.

# %%
# Calculate the range (max - min) of patient age for each insurance_provider.
# Define a custom function

# %%
# Apply the custom function

# %% [markdown]
# #### 1.5 Transformations
# The `transform` method allows applying functions to each group and returning an object with the same size as the input.

# %%
# Subtract the mean copay_amount from each appointment's copay within their insurance_provider

# %% [markdown]
# #### 1.6 Grouping by Multiple Columns
# Grouping can also be performed on multiple columns simultaneously.

# %%
# Calculate number of appointments for each doctor and each insurance provider

# %% [markdown]
# #### 1.7 Pivot Tables and Cross-Tabulations
# Pandas provides the `pivot_table` function to create pivot tables, allowing multi-dimensional analysis.

# %%
# Create a pivot table showing the number of appointments for each doctor_id and insurance_provider.

# %% [markdown]
# ### 2. Combining and Merging Datasets

# %% [markdown]
# When working with data, you often need to combine or merge multiple datasets to enrich your analysis. Pandas provides powerful tools for combining and merging datasets effectively.
#
# #### Types of Combining and Merging
# 1. **Concatenation:** Combine datasets along rows or columns.
# 2. **Merging:** Combine datasets based on key columns.
# 3. **Join:** Combine datasets based on the index.
# 4. **Append:** Add rows to a dataset.

# %% [markdown]
# #### 2.1 Concatenation
# Concatenate datasets along a specified axis (rows or columns).

# %%
# load the new_patients.xlsx file

# %%
# Adding the new set of patients to the existing patients dataframe.

# %% [markdown]
# #### 2.2 Merging
#
# Merge datasets based on common key columns using different join types:
#
# * **Inner Join:** Keep only matching rows.
# * **Outer Join:** Keep all rows, filling missing values with NaN.
# * **Left Join:** Keep all rows from the left dataset.
# * **Right Join:** Keep all rows from the right dataset.

# %%
# Merge patients and appointments using an inner join

# %%
# Left Outer join to include all patients

# %% [markdown]
# #### 2.3 Join
#
# Join datasets on their index.

# %%
# Join the two datasets by setting patient_id as the index.
# Set 'patient_id' as the index for both datasets

# %%
# Perform a left join

# %% [markdown]
# #### 2.4 Append
# Add rows to a DataFrame.

# %%
# New appointment data
new_appointments = pd.DataFrame({
    "appointment_id": ["A0051", "A0052"],
    "appointment_date": ["2023-10-15", "2023-10-16"],
    "patient_id": ["P0002", "P0010"],
    "doctor_id": ["D6", "D8"],
    "reason_for_visit": ["Checkup", "Emergency"],
    "copay_amount": [35.00, 50.00],
    "diagnosis": ["Healthy", "Asthma"]
})

# %%
# Append new appointments to the DataFrame
