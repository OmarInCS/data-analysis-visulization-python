# %% [markdown]
# # US Baby Names 1880–2010
#
# ## Objectives
# - Visualize the proportion of babies given a particular name (your own, or another name) over time

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load data of the names of each year from the folder 'babynames'
columns = ["name", "sex", "births"]
pieces = []

for year in range(1880, 2011):
    frame = pd.read_csv(f"babynames/yob{year}.txt", names=columns)
    frame["year"] = year
    pieces.append(frame)
    
names = pd.concat(pieces, ignore_index=True)
names
# Out:
#               name sex  births  year
# 0             Mary   F    7065  1880
# 1             Anna   F    2604  1880
# 2             Emma   F    2003  1880
# 3        Elizabeth   F    1939  1880
# 4           Minnie   F    1746  1880
# ...            ...  ..     ...   ...
# 1690779    Zymaire   M       5  2010
# 1690780     Zyonne   M       5  2010
# 1690781  Zyquarius   M       5  2010
# 1690782      Zyran   M       5  2010
# 1690783      Zzyzx   M       5  2010
#
# [1690784 rows x 4 columns]

# %%
# calculate total births for each sex in each year (using pivote table)
total_births_0 = names.pivot_table(values="births", index="year", columns="sex", aggfunc=sum)
total_births_0
# Out:
# sex         F        M
# year
# 1880    90993   110493
# 1881    91955   100748
# 1882   107851   113687
# 1883   112322   104632
# 1884   129021   114445
# ...       ...      ...
# 2006  1896468  2050234
# 2007  1916888  2069242
# 2008  1883645  2032310
# 2009  1827643  1973359
# 2010  1759010  1898382
#
# [131 rows x 2 columns]

# %%
total_births_0.loc[1880, "F"]
# Out:
# 90993

# %%
# calculate total births for each sex in each year (using groupby)
total_births_1 = names.groupby(["year", "sex"])["births"].sum().reset_index()
total_births_1
# Out:
#      year sex   births
# 0    1880   F    90993
# 1    1880   M   110493
# 2    1881   F    91955
# 3    1881   M   100748
# 4    1882   F   107851
# ..    ...  ..      ...
# 257  2008   M  2032310
# 258  2009   F  1827643
# 259  2009   M  1973359
# 260  2010   F  1759010
# 261  2010   M  1898382
#
# [262 rows x 3 columns]

# %% [markdown]
# ![](births-by-sex-and-year.png)

# %%
# draw a simmilar chart using seaborn library 
plt.figure(figsize=(16, 8))
sns.lineplot(data=total_births_1, x="year", y="births", hue="sex")
plt.title("Total births per year and sex")
plt.legend(labels=["Female", "Male"])
plt.grid()

# %%
# draw a simmilar chart using pandas DataFRame's 'plot' method
total_births_0.plot(title="Total births per year and sex", figsize=(16, 8))
plt.grid()

# %%
# calculate the propotion of the name births 
# to the total births of the same sex in the year
def add_prop(group):
    group["prop"] = group["births"] / group["births"].sum()
    return group

names = names.groupby(["year", "sex"]).apply(add_prop)
names
# Out:
#               name sex  births  year      prop
# 0             Mary   F    7065  1880  0.077643
# 1             Anna   F    2604  1880  0.028618
# 2             Emma   F    2003  1880  0.022013
# 3        Elizabeth   F    1939  1880  0.021309
# 4           Minnie   F    1746  1880  0.019188
# ...            ...  ..     ...   ...       ...
# 1690779    Zymaire   M       5  2010  0.000003
# 1690780     Zyonne   M       5  2010  0.000003
# 1690781  Zyquarius   M       5  2010  0.000003
# 1690782      Zyran   M       5  2010  0.000003
# 1690783      Zzyzx   M       5  2010  0.000003
#
# [1690784 rows x 5 columns]

# %%
# verify that the sum is 1 for each group
names.groupby(["year", "sex"]).prop.sum()
# Out:
# year  sex
# 1880  F      1.0
#       M      1.0
# 1881  F      1.0
#       M      1.0
# 1882  F      1.0
#             ...
# 2008  M      1.0
# 2009  F      1.0
#       M      1.0
# 2010  F      1.0
#       M      1.0
# Name: prop, Length: 262, dtype: float64

# %%
# trim each group to the top 1000 names
def get_top1000(group):
    return group.sort_values("prop", ascending=False).head(1000)

top1000 = names.groupby(["year", "sex"]).apply(get_top1000)
top1000.reset_index(drop=True, inplace=True)
top1000
# Out:
#              name sex  births  year      prop
# 0            Mary   F    7065  1880  0.077643
# 1            Anna   F    2604  1880  0.028618
# 2            Emma   F    2003  1880  0.022013
# 3       Elizabeth   F    1939  1880  0.021309
# 4          Minnie   F    1746  1880  0.019188
# ...           ...  ..     ...   ...       ...
# 261872     Camilo   M     194  2010  0.000102
# 261873     Destin   M     194  2010  0.000102
# 261874     Jaquan   M     194  2010  0.000102
# 261875     Jaydan   M     194  2010  0.000102
# 261876     Maxton   M     193  2010  0.000102
#
# [261877 rows x 5 columns]

# %%
# separate males and females in two different DataFrames
boys = top1000[top1000["sex"] == "M"]
girls = top1000[top1000["sex"] == "F"]

# %%
# calculate total births for each name in each year
total_births = top1000.pivot_table(values="births", index="year", columns="name", aggfunc=sum)
total_births.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131 entries, 1880 to 2010
# Columns: 6868 entries, Aaden to Zuri
# dtypes: float64(6868)
# memory usage: 6.9 MB

# %%
# choose any 4 names to show their total births
# example: ('John', 'Harry', 'Mary', 'Marilyn')
names4 = total_births[['John', 'Harry', 'Mary', 'Marilyn']]
names4
# Out:
# name     John   Harry    Mary  Marilyn
# year
# 1880   9701.0  2158.0  7092.0      NaN
# 1881   8795.0  2002.0  6948.0      NaN
# 1882   9597.0  2246.0  8179.0      NaN
# 1883   8934.0  2116.0  8044.0      NaN
# 1884   9427.0  2338.0  9253.0      NaN
# ...       ...     ...     ...      ...
# 2006  15140.0   414.0  4073.0    596.0
# 2007  14405.0   443.0  3665.0    597.0
# 2008  13273.0   379.0  3478.0    543.0
# 2009  12048.0   383.0  3132.0    519.0
# 2010  11424.0   363.0  2826.0    531.0
#
# [131 rows x 4 columns]

# %% [markdown]
# ![](names-births-per-year.png)

# %%
# draw a simmilar chart using 'seaborn' library
names4_st = names4.stack().reset_index().rename(columns={0: "births"})
plt.figure(figsize=(16, 8))
sns.lineplot(data=names4_st, x="year", y="births", hue="name")
plt.title("Number of births per year")
plt.grid()

# %%
# draw same data using pandas DataFrame's 'plot' method
names4.plot(title="Number of births per year", figsize=(16, 8), grid=True)
# Out:
# <AxesSubplot:title={'center':'Number of births per year'}, xlabel='year'>

# %%
# calculate total prop for each sex in each year
prop_total = top1000.pivot_table(values="prop", index="year", columns="sex", aggfunc=sum)
prop_total
# Out:
# sex          F         M
# year
# 1880  1.000000  0.997375
# 1881  1.000000  1.000000
# 1882  0.998702  0.995646
# 1883  0.997596  0.998566
# 1884  0.993156  0.994539
# ...        ...       ...
# 2006  0.753153  0.860368
# 2007  0.745959  0.855159
# 2008  0.740933  0.850003
# 2009  0.737290  0.845256
# 2010  0.736780  0.843156
#
# [131 rows x 2 columns]

# %% [markdown]
# ![](top1000-prop-by-year-and-sex.png)

# %%
# draw a simmilar chart using pandas DataFrame's 'plot' method
prop_total.plot(title="Total 1000 top prop by sex", figsize=(16, 8), yticks=np.linspace(0, 1.3, 13), grid=True)
# Out:
# <AxesSubplot:title={'center':'Total 1000 top prop by sex'}, xlabel='year'>

# %% [markdown]
# #### another interesting metric is the number of distinct names that represent 50% of the names

# %%
# calculate how many distinct male names that represent 50% of the names in 2010
subset_2010 = boys[boys["year"] == 2010]
subset_2010.sort_values("prop", ascending=False).prop.cumsum().values.searchsorted(0.5)
# Out:
# 116

# %%
# calculate how many distinct male names that represent 50% of the names in 1900 
subset_1900 = boys[boys["year"] == 1900]
subset_1900.sort_values("prop", ascending=False).prop.cumsum().values.searchsorted(0.5)
# Out:
# 24

# %%
# apply the same for each year and sex
def get_50pct_count(group):
    return group.sort_values("prop", ascending=False).prop.cumsum().values.searchsorted(0.5)

diver = top1000.groupby(["year", "sex"]).apply(get_50pct_count).unstack()
diver
# Out:
# sex     F    M
# year
# 1880   37   13
# 1881   37   13
# 1882   37   14
# 1883   38   14
# 1884   38   15
# ...   ...  ...
# 2006  208   98
# 2007  222  102
# 2008  233  108
# 2009  240  113
# 2010  245  116
#
# [131 rows x 2 columns]

# %% [markdown]
# ![](number-of-popular-names-in-top-50-pct.png)

# %%
# draw a simmilar chart using pandas DataFrame's 'plot' method
diver.plot(title="number of names that form 50%", figsize=(16, 8))
# Out:
# <AxesSubplot:title={'center':'number of names that form 50%'}, xlabel='year'>

# %% [markdown]
# ## Independent Practice
# - load the dataset of 'movieslens'
# - think of some interesting question
# - draw appropriate charts to answer them
