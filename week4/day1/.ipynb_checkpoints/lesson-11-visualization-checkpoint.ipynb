# %% [markdown]
# # Plotting and Visualization
#
# ### Objectives:
# - Choosing the chart type
# - Figures and Subplots
# - Adjusting the spacing around subplots
# - Colors, Markers, and Line Styles
# - Ticks, Labels, and Legends

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Guide for choosing chart type
#
# https://www.data-to-viz.com/#scatter
#
# ![](assets/chart-selection-diagram.png)

# %% [markdown]
# ## Bar Chart

# %%
# read bar chart data
data = pd.read_csv("charts_data/bar_chart_data.csv")
data
# Out:
#            Brand  Cars Listings
# 0           Audi            419
# 1            BMW            636
# 2  Mercedes-Benz            820
# 3     Mitsubishi            306
# 4        Renault            438
# 5         Toyota            509
# 6     Volkswagen            875

# %%
# set the figure size

# create bar chart

# set font-size 14 and rotation 45 for xticks

# set font-size 14 for yticks

# set chart title with font-size 16 and bold

# set yaxis label and font-size 14

# show the chart

# %% [markdown]
# ### MAKE SURE YOUR CHART ISN’T MISLEADING
#
# <img src="assets/bad-bars.png" width="300"> <img src="assets/good-bars.png" width="300">

# %% [markdown]
# ## Pie Chart
#    - APPROPRIATE FOR NON-TECHNICAL AUDIENCES
#    - A FEW CATEGORIES
#    - DATA SUMS UP TO 100%
#    - DON’T USE WHEN THERE ARE TOO MANY CATEGORIES
#    - NO 3D OR DOUGHNUT

# %%
# read pie chart data
data = pd.read_csv("charts_data/pie_chart_data.csv")
data
# Out:
#   Engine Fuel Type  Number of Cars
# 0           Diesel            2019
# 1              Gas             613
# 2            Other             154
# 3           Petrol            1559

# %%
# set the figure size

# create pie chart and show percentages rounded to 1 decimal place, and with suitable text format


# show legends

# set chart title

# show the chart

# %% [markdown]
# ### Line Chart
#    - UP TO SEVERAL CATEGORIES
#    - TIME SERIES DATA
#    - Y-AXIS DOESN’T HAVE TO START AT 0
#    - BE CAREFUL NOT TO INCLUDE TOO MANY CATEGORIES, TO AVOID A SPAGHETTI CHART

# %%
# read line chart data
data = pd.read_csv("charts_data/line_chart_data.csv")
data
# Out:
#             Date   GSPC500   FTSE100
# 0       1/3/2000  0.003264  0.000000
# 1       1/4/2000 -0.009549  0.000000
# 2       1/5/2000 -0.038345 -0.038137
# 3       1/6/2000  0.001922 -0.019502
# 4       1/7/2000  0.000956 -0.013571
# ...          ...       ...       ...
# 2865  12/27/2010 -0.002282  0.002135
# 2866  12/28/2010  0.003539  0.000000
# 2867  12/29/2010 -0.000254  0.000000
# 2868  12/30/2010  0.000524 -0.002080
# 2869  12/31/2010 -0.002128 -0.004236
#
# [2870 rows x 3 columns]

# %%
# convert Date column to datetime datatype

# get data in the interval '2008-07-01' to '2008-12-31'

# %%
# set the figure size

# add trace for GSPC500

# add trace for FTSE100

# set chart title and axis labels

# set legends

# show chart

# %% [markdown]
# ## Histogram
#    - START WITH A VERY LARGE NUMBER TO OBSERVE THE DATA PATTERN
#    - REDUCE THE NUMBER
#    - CHOOSE SEVERAL BINS, SUCH THAT THE PATTERN IN THE DATA IS VISIBLE

# %%
# read histogram data
data = pd.read_csv("charts_data/histogram_data.csv")
data
# Out:
#        ID  Building Type  Year of sale  Month of sale Type of property  \
# 0    1030              1        2005.0           11.0        Apartment
# 1    1029              1        2005.0           10.0        Apartment
# 2    2002              2        2007.0            7.0        Apartment
# 3    2031              2        2007.0           12.0        Apartment
# 4    1049              1        2004.0           11.0        Apartment
# ..    ...            ...           ...            ...              ...
# 262  5044              5           NaN            NaN        Apartment
# 263  5047              5           NaN            NaN        Apartment
# 264  5048              5           NaN            NaN        Apartment
# 265  5050              5           NaN            NaN        Apartment
# 266  5051              5           NaN            NaN        Apartment
#
#      Property #  Area (ft.)  Price
# 0            30      743.09    246
# 1            29      756.21    246
# 2             2      587.28    209
# 3            31     1604.75    453
# 4            49     1375.45    467
# ..          ...         ...    ...
# 262          44     1238.58    323
# 263          47      794.52    279
# 264          48     1013.27    288
# 265          50     1074.71    366
# 266          51      789.25    199
#
# [267 rows x 8 columns]

# %%
# set the figure size

# create histogram of prices (try different bins) and set color to #31be9f

# set x-axis range 100-600 

# set title and labels
plt.title("Distribution of Real Estate Prices", fontsize = 14, weight = "bold")
plt.xlabel("Price in (000's $)")
plt.ylabel("Number of Properties")
# remove top and right borders

# show the chart

# %% [markdown]
# ## Scatter Plot
#    - DISPLAYS EACH POINT FROM THE DATA, INSTEAD OF SHOWING AGGREGATED FORM
#    - SHOWS RELATIONSHIP BETWEEN VARIABLES
#    - A THIRD VARIABLE COULD BE USED WITH A COLOR PARAMETER

# %%
# read scatter data
data = pd.read_csv("charts_data/scatter_data.csv")
data
# Out:
#        ID  Building Type  Year of sale  Month of sale Type of property  \
# 0    1030              1        2005.0           11.0        Apartment
# 1    1029              1        2005.0           10.0        Apartment
# 2    2002              2        2007.0            7.0        Apartment
# 3    2031              2        2007.0           12.0        Apartment
# 4    1049              1        2004.0           11.0        Apartment
# ..    ...            ...           ...            ...              ...
# 262  5044              5           NaN            NaN        Apartment
# 263  5047              5           NaN            NaN        Apartment
# 264  5048              5           NaN            NaN        Apartment
# 265  5050              5           NaN            NaN        Apartment
# 266  5051              5           NaN            NaN        Apartment
#
#      Property #  Area (ft.)      Price    Status
# 0            30      743.09  246.17268     Sold
# 1            29      756.21  246.33190     Sold
# 2             2      587.28  209.28091     Sold
# 3            31     1604.75  452.66701     Sold
# 4            49     1375.45  467.08331     Sold
# ..          ...         ...        ...       ...
# 262          44     1238.58  322.61074  Not Sold
# 263          47      794.52  279.19126  Not Sold
# 264          48     1013.27  287.99653  Not Sold
# 265          50     1074.71  365.86878  Not Sold
# 266          51      789.25  199.21640  Not Sold
#
# [267 rows x 9 columns]

# %%
# set figure size
plt.figure(figsize = (12, 8))

# create scatter plot btw Area and Price of each building type

# add legends

# set title and labels
plt.title("Relationship between Area and Price of California Real Estate", 
          fontsize = 14, 
          weight = "bold")
plt.xlabel("Area (sq. ft.)", weight = "bold")
plt.ylabel("Price (000's of $)")
# show chart
plt.show()

# %% [markdown]
# ## SubPlots

# %%
# read the tips.csv file
data = pd.read_csv("charts_data/tips.csv")
data
# Out:
#      total_bill   tip smoker   day    time  size
# 0         16.99  1.01     No   Sun  Dinner     2
# 1         10.34  1.66     No   Sun  Dinner     3
# 2         21.01  3.50     No   Sun  Dinner     3
# 3         23.68  3.31     No   Sun  Dinner     2
# 4         24.59  3.61     No   Sun  Dinner     4
# ..          ...   ...    ...   ...     ...   ...
# 239       29.03  5.92     No   Sat  Dinner     3
# 240       27.18  2.00    Yes   Sat  Dinner     2
# 241       22.67  2.00    Yes   Sat  Dinner     2
# 242       17.82  1.75     No   Sat  Dinner     2
# 243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
# draw a line chart of the tip column's comulative sum

# %%
# group the tips by day and draw a bar chart showing tips of each day

# %%
# with the same groups draw a horizontal bar chart, try to change height and color

# %%
# create 2 * 2 subplot then add the earlier charts to each in a subplot

# %%
# do the same, using the axises

# %%
# do the same, but add all subplots at once, then customize line type, title and spaces

# %% [markdown]
# ## Independent Practice
# - explore the data from 'tips.csv'
# - state some questions and draw charts to answer them
